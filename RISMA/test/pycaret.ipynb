# %%
import pandas as pd
from pycaret.regression import *

path = "/Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/Sentinel-1-Prep.csv"
data = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/pycaret.ipynb Cell 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/pycaret.ipynb#ch0000000?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/pycaret.ipynb#ch0000000?line=1'>2</a> from pycaret.regression import *
#       <a href='vscode-notebook-cell:/Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/pycaret.ipynb#ch0000000?line=3'>4</a> path = "/Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/Sentinel-1-Prep.csv"
#       <a href='vscode-notebook-cell:/Users/alperbalmumcu/Github/sen1-sen2-soil-moisture/RISMA/pycaret.ipynb#ch0000000?line=4'>5</a> data = pd.read_csv(path)
#
# ...
